# %% [markdown]
# ## Build a Regression model that predicts the profit of startup on basis of investment they have made in RND(research and Development)

# %%
#Step 1 : Data gathering
path=r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/50_Startups.csv"
import pandas as pd
df=pd.read_csv(path)
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# Perform basic data quality check

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     str
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 2.1 KB

# %%
## separate x and y features
#x: RND 
#y: profit

# %%
x= df[['RND']]
y= df[['Profit']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 x= df[['RND']]
# ----> 2 y= df[['Profit']]
#
# File c:\Users\anuve\OneDrive\Desktop\ANUSHKA\3RI (DATA SCIENCE)\ML practice\repository\venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\anuve\OneDrive\Desktop\ANUSHKA\3RI (DATA SCIENCE)\ML practice\repository\venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...
