# %% [markdown]
# #### Business Statement :Build a predictive model that prescribes the drug to patients the drug to patients

# %% [markdown]
# Decision tree classifier model
# Data gathering
# Perform basic data quality checks
# Separate X and Y features.
# Splitting data into training and testing
# training : 60-90
# testing : 40-10%
# Feature Engg ..cleaning,preprocessing
# model building
# Hyperparameter tuning
# Model Evualution
# Save the model and preprocessor pipeline

# %%
path = r"https://raw.githubusercontent.com/kolteanushkaa/Datasets/refs/heads/main/drug200.csv"
import pandas as pd
df = pd.read_csv(path)
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.duplicated().sum()

# %%
df.isna().sum()

# %%
df = df.drop_duplicates()

# %%
X = df.drop(columns=["Drug"])
y = df["Drug"]

# %%
X.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
X_train.head()

# %%
Print(f"X_train shape: {X_train.shape}")
Print(f"X_test shape: {X_test.shape}")
Print(f"y_train shape: {y_train.shape}")
Print(f"y_test shape: {y_test.shape}")

# %%
y_test.head()

# %%
xtrain.select_dtypes(include="object").columns

# %%
list(X_train.select_dtypes(include="object").columns)

# %%
from sklearn.pipelines import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

cat = X_train.select_dtypes(include="object").columns
con = X_train.select_dtypes(include="number").columns
cat_pipe = Pipeline(
    SimpleImputer(strategy= 'mean')
    StandardScaler()
)
con_pipe = Pipeline(
    SimpleImputer(strategy= 'most_frequent')
    OneHotEncoder(handle_unknown= 'ignore', sparse_output= False)
)

preprocessor = ColumnTransformer(
    ("cat", cat_pipe, cat),
    ("con", con_pipe, con
)).set_output(transform="pandas")

# %%
X_train_pre = preprocessor.fit(X_train)
X_train_pre.head()

# %%
X_test_pre = preprocessor.transform(X_test)
X_test_pre.head()

# %% [markdown]
# Hyperparameter Tuning

# %%
params = {
    "criterion": ["gini", "entropy"],
    "max_depth": [None, 5, 10, 15],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

# %%
params

# %% [markdown]
# criteria : Gini
# Max_depth : 3
# min_samples_splits : 1
# min_samples_leaf : 2

# %%
from sklearn.metrics import f1_score 
ypred = model.predict(X_test_pre)
f1_score(y_test, ypred, average="macro")
f1_score

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model, X_test_pre, y_test)
print(classification_report(y_test, ypred))

# %%
import joblib
joblib.dump(model, "decision_tree_model.joblib")
joblib.dump(preprocessor, "preprocessor.joblib")
